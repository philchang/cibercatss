# %% [markdown]
# # Linear Regression from Scratch
# This notebook walks through a beginner-friendly implementation of linear regression using Python and NumPy.

# %% [markdown]
# ## Step 1: Generate Synthetic Dataset
# We simulate a dataset where the true relationship is linear with some noise added.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score

# Generate data
np.random.seed(0)
X = np.random.rand(50) * 10
true_slope = 2
true_intercept = 1
noise = np.random.randn(50) * 2
y = true_slope * X + true_intercept + noise

# %% [markdown]
# ## Step 2: Compute Slope and Intercept
# We compute the best-fit line using the closed-form solution of linear regression.

# %%
x_mean = np.mean(X)
y_mean = np.mean(y)

numerator = np.sum((X - x_mean) * (y - y_mean))
denominator = np.sum((X - x_mean)**2)
w = numerator / denominator
b = y_mean - w * x_mean

# %% [markdown]
# ## Step 3: Make Predictions
# We use the learned slope and intercept to predict values for X.

# %%
y_pred = w * X + b

# %% [markdown]
# ## Step 4: Plot the Results with Error Lines
# We visualize the actual data, the predicted line, and the error lines between them.

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X, y, label='Actual data')
plt.plot(X, y_pred, color='red', linewidth=2, label='Prediction line')
for i in range(len(X)):
    plt.plot([X[i], X[i]], [y[i], y_pred[i]], color='gray', linestyle='--', linewidth=0.5)
plt.xlabel("X")
plt.ylabel("y")
plt.title("Linear Regression with Error Lines")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 5: Evaluate the Model
# We use Mean Squared Error (MSE) and R-squared (R²) to evaluate the performance.

# %%
mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)

print(f" Learned slope (w): {w:.2f}")
print(f" Learned intercept (b): {b:.2f}")
print(f" Mean Squared Error (MSE): {mse:.2f}")
print(f" R-squared (R²): {r2:.2f}")
# Out:
#  Learned slope (w): 1.94
#  Learned intercept (b): 0.99
#  Mean Squared Error (MSE): 3.42
#  R-squared (R²): 0.89

# %% [markdown]
# ## 🎨 Creative Exercise – Regression Artist
#
# Let's make regression fun and visual! In this exercise, you will become a **Regression Artist**:
#
# ### 🎯 Your Goal:
# Design a dataset that makes your linear regression model perform *poorly* — even though it **looks linear** at a glance.
#
# You can control:
# - The slope (`w`)
# - The intercept (`b`)
# - The noise level (`noise_scale`)
#
# ### 🔍 Explore:
# - How do noise and outliers affect the model?
# - What happens to the Mean Squared Error and R² score?

# %%
# Run this cell multiple times with different settings
def generate_data(w=1.5, b=2.0, noise_scale=1.0, n_points=50):
    np.random.seed(7)
    X = np.random.rand(n_points) * 10
    y = w * X + b + np.random.randn(n_points) * noise_scale
    return X, y

# Try adjusting these values
w_custom = 1.5
b_custom = 2.0
noise_scale_custom = 4.0
X_custom, y_custom = generate_data(w_custom, b_custom, noise_scale_custom)

# Fit a line
x_mean = np.mean(X_custom)
y_mean = np.mean(y_custom)
numerator = np.sum((X_custom - x_mean) * (y_custom - y_mean))
denominator = np.sum((X_custom - x_mean)**2)
w_model = numerator / denominator
b_model = y_mean - w_model * x_mean
y_pred_custom = w_model * X_custom + b_model

# Plot
plt.figure(figsize=(10, 6))
plt.scatter(X_custom, y_custom, label='Your Data')
plt.plot(X_custom, y_pred_custom, color='red', label='Prediction Line')
for i in range(len(X_custom)):
    plt.plot([X_custom[i], X_custom[i]], [y_custom[i], y_pred_custom[i]], color='gray', linestyle='--', linewidth=0.5)
plt.title("Your Regression Art")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Evaluate
mse_custom = mean_squared_error(y_custom, y_pred_custom)
r2_custom = r2_score(y_custom, y_pred_custom)
print(f"📉 MSE: {mse_custom:.2f} | 🎯 R²: {r2_custom:.2f}")
# Out:
# 📉 MSE: 15.77 | 🎯 R²: 0.48

# %% [markdown]
# ## Regression Artist
#
# This activity helps you **internalize how regression works** by switching roles — from modeler to **data creator**.
#
# ---
#
# ### Learning Objectives
# By the end of this activity, you should be able to:
# - Understand how noise, slope, and intercept affect regression fit
# - Explain how MSE and R² reflect model performance
# - Recognize the limits of linear regression
# - Apply creative reasoning in designing datasets
#
# ---
#
# ### Your Challenge
# > Create a dataset that looks *linear* at a glance — but makes your regression model perform poorly.
#
# You can modify:
# - `w` → the true slope
# - `b` → the true intercept
# - `noise_scale` → the amount of random noise
#
# Observe how:
# - The regression line responds
# - The **error lines**, **MSE**, and **R²** change
#
# ---
#
# ### Reflect and Discuss
# After running your model, consider:
# - What made your model perform poorly?
# - How sensitive was the line to noise?
# - Can a dataset have high R² but still be misleading?
# - How does this relate to real-world data?
#
# ---
#
# ### Takeaways
# - Regression assumes a **linear, noise-limited world**
# - Visuals can deceive — always evaluate with metrics
# - You are not just a model user; you're a **data designer**
# - R² ≈ "How much variation in y is explained by x?"
