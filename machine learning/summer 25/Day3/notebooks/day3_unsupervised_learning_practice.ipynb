# %% [markdown]
# # Unsupervised Learning Practice Notebook

# %% [markdown]
# # Day 3: Unsupervised Learning – Practice Notebook
#
# Welcome to Day 3! Today we'll explore unsupervised learning algorithms with hands-on coding. We'll focus on **dimensionality reduction techniques**: PCA and t-SNE.

# %%
##  1. Setup and Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %matplotlib inline
sns.set(style='whitegrid')

# %%
##  2. Load and Explore Dataset
#We'll use the classic **Iris dataset**, which contains 4 features and 3 species of flowers.


iris = load_iris()
X = pd.DataFrame(iris.data, columns=iris.feature_names)
y = pd.Series(iris.target, name="species")

print(X.head())
print("Target Classes:", iris.target_names)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# Target Classes: ['setosa' 'versicolor' 'virginica']

# %%
## 3. Standardize the Data
#Most unsupervised learning techniques (like PCA and t-SNE) require features to be on the same scale.


scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
## 4. Principal Component Analysis (PCA)
#Reduce from 4D → 2D and visualize the structure.


pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

pca_df = pd.DataFrame(X_pca, columns=["PC1", "PC2"])
pca_df["species"] = y

plt.figure(figsize=(8, 6))
sns.scatterplot(data=pca_df, x="PC1", y="PC2", hue="species", palette="Set2")
plt.title("PCA - 2D Projection of Iris Dataset")
plt.show()

print("Explained Variance Ratio:", pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio: [0.72962445 0.22850762]

# %% [markdown]
# ## 5. t-Distributed Stochastic Neighbor Embedding (t-SNE)

# %%
tsne = TSNE(n_components=2, perplexity=30, learning_rate=200, random_state=42)
X_tsne = tsne.fit_transform(X_scaled)

tsne_df = pd.DataFrame(X_tsne, columns=["Dim1", "Dim2"])
tsne_df["species"] = y

plt.figure(figsize=(8, 6))
sns.scatterplot(data=tsne_df, x="Dim1", y="Dim2", hue="species", palette="Set1")
plt.title("t-SNE - 2D Projection of Iris Dataset")
plt.show()

# %% [markdown]
# ## 6. Practice Challenge
#
# Try changing the following:
# - `perplexity` (e.g., 5, 30, 50) in t-SNE
# - `n_components=3` in PCA and plot in 3D
# - Try running both on other datasets (e.g., wine dataset)

# %% [markdown]
# ## 📎 Summary
#
# - **PCA** is linear and preserves global structure.
# - **t-SNE** is nonlinear and better for capturing local clusters.
# - Dimensionality reduction helps visualize and understand high-dimensional data.
#
# Good luck!
