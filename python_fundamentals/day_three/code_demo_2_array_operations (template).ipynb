# %%
import numpy as np

def array_operations(n, operation):
    if operation == "square":
        # Create array of squares
        pass
    elif operation == "multiply":
        # Create multiplication table
        pass
    elif operation == "identity":
        # Create identity matrix
        pass
    else:
        raise ValueError("Invalid operation!")

    return array

# Test cases
print(array_operations(4, "square"))
print(array_operations(5, "multiply"))
print(array_operations(3, "identity"))
