# %%
import numpy as np

def matrix_operations(matrix_a, matrix_b):
    # Multiply matrix_a by scalar value of 3
   

    # Add 5 to matrix_b
   
    # Calculate element-wise product of matrix_a and matrix_b
    
    # Compute dot product of element_wise_product and transposed matrix_a
    
    return dot_product

# Example usage
a = np.array([[1, 2], [3, 4]])
b = np.array([[5, 6], [7, 8]])
result = matrix_operations(a, b)
print(result)
